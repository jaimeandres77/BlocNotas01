# %% [markdown]
# <a href="https://colab.research.google.com/github/jaimeandres77/BlocNotas01/blob/master/Copia_de_Primera_Clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Configurar folder de imagenes**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **Importar las librerias**

# %%
# importar librerias necesarias
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

#graficar imagenes estadisticas en el notebook
# %matplotlib inline

# %% [markdown]
# **Formar habitual de leer y mostar una imagen(error en colab)**

# %%
image= cv2.imread('/content/drive/My Drive/PDI/MAMBA.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=920x1013 at 0x7F512F410E10>

# %% [markdown]
# **Como cambiar rutas de folders y archivos opcion 1**

# %%
# !pwd
# !ls
#%cd ../
# %cd /content/drive/My Drive/PDI/
# !pwd

img= cv2.imread('MAMBA.png', cv2.IMREAD_UNCHANGED)
img= cv2.resize(img,(int(300), int(300)))
cv2_imshow(img)
# Out:
# /content/drive/My Drive/PDI
# MAMBA.png
# /content/drive/My Drive/PDI
# /content/drive/My Drive/PDI
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F512EB84A58>
